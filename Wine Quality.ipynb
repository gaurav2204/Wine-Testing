# %% [markdown]
# ## WINE Quality
#
# This is one of the most popular datasets along data science beginners. It is divided into 2 datasets.<br>                We can perform data analysis on this data. There are 1599,4898 rows and 12 columns in each dataset.
#
# **Problem:** Predict the quality of the wine.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %%
# read both csv file red winequality
df_red = pd.read_csv('winequality-red.csv')

# read both csv file White winequality
df_white = pd.read_csv('winequality-white.csv')

# %%
df_red.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
df_white.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...

# %%
print("{} Unseprated red_wine column ".format(df_red.shape))
print('\n')
print("{} Unseprated white_wine column ".format(df_white.shape))
# Out:
# (1599, 1) Unseprated red_wine column
#
#
# (4898, 1) Unseprated white_wine column

# %%
# read  csv file red winequality to seperate column
df_red = pd.read_csv('winequality-red.csv', sep =';')

df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Rename the column in proper manner
df_red.rename(columns={'fixed acidity': 'fixed_acidity','volatile acidity': 'volatile_acidity','citric acid': 'citric_acid','residual sugar': 'residual_sugar',
                  'free sulfur dioxide': 'free_sulfur_dioxide','total sulfur dioxide': 'total_sulfur_dioxide'}, inplace=True)
df_red.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# read  csv file white winequality to seperate column
df_white = pd.read_csv('winequality-white.csv', sep =';')


df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Rename the column in proper manner
df_white.rename(columns={'fixed acidity': 'fixed_acidity','volatile acidity': 'volatile_acidity','citric acid': 'citric_acid','residual sugar': 'residual_sugar',
                  'free sulfur dioxide': 'free_sulfur_dioxide','total sulfur dioxide': 'total_sulfur_dioxide'}, inplace=True)
df_white.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
print("{} of Rows and {} seprated red_wine column ".format(df_red.shape[0],df_red.shape[1]))
print('\n')
print("{} of Rows and {} seprated white_wine column ".format(df_white.shape[0],df_white.shape[1]))
# Out:
# 1599 of Rows and 12 seprated red_wine column
#
#
# 4898 of Rows and 12 seprated white_wine column

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed_acidity           1599 non-null float64
# volatile_acidity        1599 non-null float64
# citric_acid             1599 non-null float64
# residual_sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free_sulfur_dioxide     1599 non-null float64
# total_sulfur_dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed_acidity           4898 non-null float64
# volatile_acidity        4898 non-null float64
# citric_acid             4898 non-null float64
# residual_sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free_sulfur_dioxide     4898 non-null float64
# total_sulfur_dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_red.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_white.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_red.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_white.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# To check null value in the datafile
df_red.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# To check null value in the datafile
df_white.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# to check duplicate in both data file
print("{} duplicate in red wine quality".format(df_red.duplicated().sum()))
print('\n')
print("{} duplicate in  white wine quality".format(df_white.duplicated().sum()))
# Out:
# 240 duplicate in red wine quality
#
#
# 937 duplicate in  white wine quality

# %%
# to check the unique value in both data file
print("0{} unique value in red wine quality".format(df_red.quality.nunique()))
print('\n')
print("0{} unique value in white wine quality".format(df_white.quality.nunique()))
# Out:
# 06 unique value in red wine quality
#
#
# 07 unique value in white wine quality

# %%
# To insert a new column in red wine dataframe name color in which we easily Analysis color when we join data frame
# DataFrame.insert(loc, column, value, allow_duplicates=False)  use this format
df_red.insert(12, 'color', 'Red')
df_red.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
df_white.insert(12, 'color', 'White')
df_white.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  White
# 1      9.5        6  White
# ...

# %%
df_red.hist(figsize = (15,15),color = 'red');

# %%
df_white.hist(figsize = (15,15),color = 'grey');

# %%
# To combine both data farames in one data frames 
# use append dataframes to combine two dataframes
df = df_red.append(df_white)

# To check combine dataframes
df.head()
df.tail()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
# fixed_acidity           6497 non-null float64
# volatile_acidity        6497 non-null float64
# citric_acid             6497 non-null float64
# residual_sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free_sulfur_dioxide     6497 non-null float64
# total_sulfur_dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6497 non-null float64
# sulphates               6497 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# color                   6497 non-null object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %% [markdown]
# In wines contain varying proportions of sugars, alcohol, organic acids, salts from mineral and organic acids, phenolic compounds, pigments, nitrogenous substances, pectins, gums, mucilage, volatile aromatic compounds (esters, aldehydes and ketones), vitamins, salts and sulfur dioxide.
#
# In wine tasting, the term acidity refers to the fresh, tart and sour attributes of the wine. Three primary acids are found in wine grapes — tartaric, malic and citric acids. They are evaluated in relation to how well the acidity balances out the sweetness and bitter components of the wine, such as tannins.
#
# **Fixed Acidity**
# Titratable acidity, sometimes referred to as fixed acidity, is a measurement of the total concentration of titratable acids and free hydrogen ions present in your wine. A litmus paper can be used to identify whether a given solution is acidic or basic. The most common titratable acids are tartaric, malic, citric and carbonic acid. These acids, along with many more in smaller quantities, either occur naturally in the grapes or are created through the fermentation process.
#
# **Residual Sugars**
# Residual Sugar, or RS for short, refers to any natural grape sugars that are leftover after fermentation ceases (whether on purpose or not). The juice of wine grapes starts out intensely sweet, and fermentation uses up that sugar as the yeasts feast upon it.
#
# During winemaking, yeast typically converts all the sugar into alcohol making a dry wine. However, sometimes not all the sugar is fermented by the yeast, leaving some sweetness leftover.
#
# To make a wine that tastes good, the key is to have a perfect balance between the sweetness and the sourness in the drink.
#
# **Chlorides**
# The amount of chlorides present in a wine is usually an indicator of its “saltiness.” This is usually influenced by the territory where the wine grapes grew, cultivation methods, and also the grape type. Too much saltiness is considered undesirable. The right proportion can make the wine more savory.
#
# **Sulphur Dioxide levels**
# sulfur dioxide (SO2) is widely accepted as a useful winemaking aide. It is used as a preservative because of its anti-oxidative and anti-microbial properties in wine, but also as a cleaning agent for barrels and winery facilities.<Br>
#
#                             total SO2 = free SO2 + bound SO2
#
#     The free SO2 portion (not associated with wine molecules) is effectively the buffer against microbes and oxidation. Whereas the bound SO2 portion (associated with wine molecules) is the part which has already done its work and cannot be useful any longer in this context.
#
# **pH**
# pH stands for power of hydrogen, which is a measurement of the hydrogen ion concentration in the solution. Generally, solutions with a pH value less than 7 are considered acidic, with some of the strongest acids being close to 0. Solutions above 7 are considered alkaline or basic. The pH value of water is 7, as it is neither an acid nor a base.
#
# **Alcohol**
# Alcohol — the key to a successful party! Alcoholic beverages existed from at least 10,000 BC. Drinking it in small amounts gives you warm fuzzy feelings inside, and makes you more sociable. Of-course, higher doses can also make you pass out.
# the characteristics of red and white and taste best at concentrations between 11.5 and 13.5 percent. Good syrah vintages are found with alcohol content between 12.5 and 15.5 percent. Look for ripe merlot wines with higher alcohol concentrations between 13.0 and 14.5 percent.

# %%
# to check the total row 
df.shape
# Out:
# (6497, 13)

# %%
# to check duplicate
print("{} of duplicate in wine quality".format(df.duplicated().sum()))
# Out:
# 1177 of duplicate in wine quality

# %%
# to check the unique value
print("{} unique value in wine quality".format(df.quality.nunique()))
# Out:
# 7 unique value in wine quality

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# To take rating of the wine quality

rating = [(df['quality'] >= 5) & (df['quality'] <= 6),(df['quality'] < 5)]
wine_rating = ['Medium', 'low']
df['wine_rating'] = np.select(rating, wine_rating, default='High')
df.wine_rating.value_counts()
# Out:
# Medium    4974
# High      1277
# low        246
# Name: wine_rating, dtype: int64

# %% [markdown]
# ## Correlation Heat Maps - Using Seaborn
# **Corelation between features/variables:**

# %%
correlation = df.corr()
plt.figure(figsize=(12, 5))
sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap="RdBu_r")

# %%
# use quality for correlation observation
correlation['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.444319
# citric_acid             0.085532
# free_sulfur_dioxide     0.055463
# sulphates               0.038485
# pH                      0.019506
# residual_sugar         -0.036980
# total_sulfur_dioxide   -0.041385
# fixed_acidity          -0.076743
# chlorides              -0.200666
# volatile_acidity       -0.265699
# density                -0.305858
# Name: quality, dtype: float64

# %% [markdown]
# As We can observe that, the 'alcohol,pH, sulphates, citric_acid & fixed_acidity' have maximum correlation with response variable 'quality'.This means that, they need to be further analysed for detailed pattern and correlation exploration but we also analysis residual_sugar becuse it's important part of wine quality.

# %% [markdown]
# ## Analysis  Alcohol with other factors

# %% [markdown]
# ### Does wines with higher alcoholic content receive better ratings?

# %%
# get the median amount of alcohol content
df.alcohol.median()
# Out:
# 10.3

# %%
# select samples with alcohol content less than the median
low_alcohol = df[df.alcohol < 10.3]

# select samples with alcohol content greater than or equal to the median
high_alcohol = df[df.alcohol >= 10.3]

# ensure these queries included each sample exactly once
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
print("{} is Low quality count of Alcohol".format(low_alcohol.quality.mean()))
print("{} is High quality count of Alcohol".format(high_alcohol.quality.mean()))
# Out:
# 5.475920679886686 is Low quality count of Alcohol
# 6.146084337349397 is High quality count of Alcohol

# %%
# study the Alcohol and residual sugar behaviour with different rating

sns.lmplot(x = "alcohol", y = "residual_sugar", col = "wine_rating", data = df)

# %%
# study the Alcohol and PH behaviour with different rating

sns.lmplot(x = "alcohol", y = "pH", col = "wine_rating", data = df)

# %%
# study the Alcohol and total sulfur dioxide behaviour with different rating

sns.lmplot(x = "alcohol", y = "total_sulfur_dioxide", col = "wine_rating", data = df)

# %%
# study the Alcohol and fixed acidity with different rating

sns.lmplot(x = "alcohol", y = "fixed_acidity", col = "wine_rating", data = df)

# %% [markdown]
# ### Observation :
# `01.` 5.475920679886686 is Low quality and 6.146084337349397 is High quality count of Alcohol.In which clearly shown that high quality contains better alcohol counts.<br>
# `02,` As we observe in the graph Alcohol and residual sugar gave some positive relation with the quality rating as residual increase the alcohol level is decrease and we saw in graph it slightly moves downwards in medium quality but in low quality when sugar level is bit down and the level of alcohol little bit increase but the quality of wine is low.In high level quality alcohol is high and sugal level is down which is good for wine quality.<br>
# `03.` Alcohol and pH level both increase with the quality of wine and its not good for wine quality because higher pH level have bad affect in wine quality.<br>
# `04.` As we observe that higher the count of alcohol and lower the total sulfur dioxide and also the lower the quality of wine.<br>
# `05.` As we observe that  higher the count of alcohol and higher the value of fixed acidity but it gives good result in medium quality of wines.

# %% [markdown]
# ### Does sweeter wines receive better ratings?

# %%
# get the median amount of residual sugar
df.residual_sugar.median()
# Out:
# 3.0

# %%
# select samples with residual sugar less than the median
low_sugar = df[df.residual_sugar < 3]

# select samples with residual sugar greater than or equal to the median
high_sugar = df[df.residual_sugar >= 3]

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups

print("{} is High quality count of Residual Sugar".format(high_sugar.quality.mean()))
print("{} is Low quality count of Residual Sugar".format(low_sugar.quality.mean()))
# Out:
# 5.82782874617737 is High quality count of Residual Sugar
# 5.808800743724822 is Low quality count of Residual Sugar

# %% [markdown]
# AS we observe that residual sugar count is little increase with the quality of wine.

# %% [markdown]
# ## Residual  Sugar vs. Fixed Acidity

# %%
df.plot(x ='fixed_acidity',y ='residual_sugar',kind='scatter',figsize=(8,8));
plt.xlabel('Fixed Acidity coun');
plt.ylabel('Residual Sugar count');
plt.title('Correlation with Residual sugar and Fixed Acidity');

# %% [markdown]
# This scatter-plot shows how the values of residual_sugar change with changing fixed acidity levels. We can see that, as fixed acidity levels drop, the residual sugar is levels increase.<br>
# A lower residual sugar level is, after all, an indicator of high acidity.

# %% [markdown]
# ## Residual  Sugar vs. pH

# %%
df.plot(x ='pH',y ='residual_sugar',kind='scatter',figsize=(8,8));
plt.xlabel('PH level');
plt.ylabel('Residual Sugar count');
plt.title('Correlation with Residual sugar and PH');

# %% [markdown]
# As we observe that scatter-plot shows the values of residual_sugar change with changing PH level in a curve form.
# maximum residual sugar in between 3 to 3.2 pH level. when pH level is higher the sugar level is decrease.

# %% [markdown]
# ## Residual Sugar Vs Citric Acid

# %%
# Create a new dataframe containing only residual sugar and citric acid columns to visualize their co-relations
rs_ca = df[['residual_sugar','citric_acid']]

# using seaborn library we joint-grid with the dataframe, 
ca_rs = sns.JointGrid(y="residual_sugar", x="citric_acid", data=rs_ca, size=8)

# a regression plot in the grid 
ca_rs = ca_rs.plot_joint(sns.regplot, scatter_kws={"s": 5})

# a distribution plot in the same grid
ca_rs = ca_rs.plot_marginals(sns.distplot)

# %% [markdown]
# AS We seen in the plot clearly shown curve and maximum residual sugar in between 0.25 to 0.50 ciric acid.

# %% [markdown]
# ## Conclusion
# `01.` As we observe that Wine quality depends on multiple factors such as Alcohol,acidity,flavours etc. we analysis that alcohol and sugar factor are play very important part in the better wine quality.<br>
# `02.` High quality of alcohol produced better quality of wine.<br>
# `03.` Sugar and pH level also promote the better quality wine and Acidity play key role in both derived both factors.<br>
# `04.` In the end, wine is admired for its harmony and complexity, whether its alcohol level is low or high. Certainly, there are people who prefer either high or low alcohol styles.

# %% [markdown]
# ## Refrences
# `01.` Udacity Data Anlysis Nano degree programs
# `02.` https://seaborn.pydata.org/generated/seaborn.JointGrid.html
# `03.` https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.select.html
# `04.` https://matplotlib.org/
